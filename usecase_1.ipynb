# %% [markdown]
# # Use case one
# Databricks use cases <br>
# Tamilarasu<br>
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png) <br>
# **Bold text** <br>
# _Italics_

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
# %run /Workspace/Users/arasumtamil@gmail.com/databricks-code-repo/4_child_nb_dataload

# %%
ls /Volumes/workspace/default/usage_metrics

# %%
# %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
df=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df)

# %%
df=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df.write.saveAsTable("default.mobile_os_usage")

# %%
# %sql
select * from mobile_os_usage limit 10

# %%
def fun(text):
    return text.upper()

print(fun('databricks'))

# %%
pip install pandas
